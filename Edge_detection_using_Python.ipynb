# %% [markdown]
# <a href="https://colab.research.google.com/github/vinaysr93/fictiv/blob/main/Edge_detection_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image=cv2.imread("red1.jpeg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=899x1599>

# %%
# convert the image to grayscale format
img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=899x1599>

# %%
ret, thresh = cv2.threshold(img_gray, 150, 255, cv2.THRESH_BINARY)
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=899x1599>

# %%
contours, hierarchy = cv2.findContours(image=thresh, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_NONE)

# draw contours on the original image
image_copy = image.copy()
cv2.drawContours(image=image_copy, contours=contours, contourIdx=-1, color=(0, 255, 0), thickness=2, lineType=cv2.LINE_AA)

# see the results
cv2_imshow( image_copy)
# Out:
# <PIL.Image.Image image mode=RGB size=899x1599>
